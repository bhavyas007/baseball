# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.isna().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
duplicate_rows=df[df.duplicated(['W','R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E'])]

# %%
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, E]
# Index: []

# %% [markdown]
# there is no duplicate row

# %%
df.duplicated(['W']).any()
# Out:
# True

# %%
df.duplicated(['R']).any()
# Out:
# True

# %%
df.duplicated(['AB']).any()
# Out:
# True

# %%
df.duplicated(['H']).any()
# Out:
# True

# %%
df.duplicated(['2B']).any()
# Out:
# True

# %%
df.duplicated(['3B']).any()
# Out:
# True

# %%
df.duplicated(['HR']).any()
# Out:
# True

# %%
df.duplicated(['BB']).any()
# Out:
# True

# %%
df.duplicated(['SO']).any()
# Out:
# True

# %%
df.duplicated(['SB']).any()
# Out:
# True

# %%
df.duplicated(['RA']).any()
# Out:
# False

# %%
df.duplicated(['ER']).any()
# Out:
# False

# %%
df.duplicated(['ERA']).any()
# Out:
# False

# %%
df.duplicated(['CG']).any()
# Out:
# True

# %%
df.duplicated(['SHO']).any()
# Out:
# True

# %%
df.duplicated(['SV']).any()
# Out:
# True

# %%
df.duplicated(['E']).any()
# Out:
# True

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# as we can see there is no missing value in our dataset

# %% [markdown]
# EDA Analysis

# %%
sns.countplot(df['W'])
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='W', ylabel='count'>

# %% [markdown]
# maximum predicted wins is 68.

# %%
sns.countplot(df['R'])
plt.figure(figsize=(20,12))
plt.show()
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 696 runs has been score maximum time

# %%
sns.histplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Count'>

# %% [markdown]
# maximum AB is at 5500

# %%
sns.histplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Count'>

# %% [markdown]
# Maximum times homerun is in 1375 range

# %%
sns.histplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Count'>

# %% [markdown]
# Maximum times doubles is in range of 280 run

# %%
sns.histplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Count'>

# %%
sns.histplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Count'>

# %%
sns.histplot(df['BB'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Count'>

# %%
sns.histplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Count'>

# %%
sns.histplot(df['SB'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Count'>

# %%
sns.histplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Count'>

# %%
sns.histplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Count'>

# %%
sns.histplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Count'>

# %%
sns.histplot(df['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Count'>

# %%
sns.histplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Count'>

# %% [markdown]
# maximum no of shutout is in range of 10 to 12.5

# %%
sns.histplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Count'>

# %% [markdown]
# maximum saves is in range of 35-40 runs

# %%
sns.histplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Count'>

# %% [markdown]
# Maximum errorss is in range of 90 runs.

# %%
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize = (20,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.distplot(df[column], color = 'blue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %% [markdown]
# R,H,SO ,CG AND E are not normally distributed

# %%
plt.figure(figsize = (20,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.histplot(df[column], color = 'blue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %%
plt.figure(figsize = (20,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.scatterplot(df[column],df['W'] ,color = 'Red')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %%
plt.figure(figsize = (20,20), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        plt.figure(figsize = (10,10))
        sns.regplot(df[column], df['W'])
        plt.title('Scatter Plot of Wins vs attributes')
        plt.xlabel(column)
        plt.ylabel('W')
        
plt.tight_layout()

# %% [markdown]
# as we can see RA, ER, ERA have good relation with win. as it is forming a linear relationship, others are in scattered form

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
sns.pairplot(df,hue='W')

# %%
plt.figure(figsize=[20,15])
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# W is highly corelated with ERA, ER & RA

# %%
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %% [markdown]
# # Checking outliers

# %%
collist=df.columns
ncol=30
nrows=15

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data=df[collist[i]],orient='v')
    plt.tight_layout()

# %% [markdown]
# as we can see there are outliers present in our data

# %%
import scipy.stats as stats

# %%
from scipy.stats import zscore

# %%
stats.zscore(df)
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299
# 1   0.197838  0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967
# 2   0.003243 -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377
# 3  -0.483244 -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181
# 4  -0.677839  0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770
# 5   1.170814  3.509647 -0.104884  1.361089  1.869832 -1.391501  2.185047
# 6   0.587028  1.311430  0.732263 -0.116292 -0.153633 -1.196885  1.545833
# 7   0.003243  0.428681 -0.451289 -0.596886 -1.615025 -1.099578  1.705636
# 8  -0.094054 -0.765626 -0.451289 -0.365489  0.183611  0.068115  0.107601
# 9  -0.288649  1.034489  1.785913  1.628086  1.082929  0.165423 -0.084163
# 10  0.684326  1.086415 -0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622 -0.826562 -0.721484  0.183611 -0.515731  2.121125
# ...

# %%
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 17)

# %%
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (29, 17)

# %% [markdown]
# # checking skewness

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# as we can see only small skewness is present in our data such as in E, CG, SV,H,SHO

# %%
from sklearn.preprocessing import PowerTransformer
scaler=PowerTransformer(method='yeo-johnson')

# %%
df_new[['E','CG','SV','SHO','H']]=scaler.fit_transform(df_new[['E','CG','SV','SHO','H']].values)

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.000000
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.006996
# SHO    0.032659
# SV    -0.033949
# E     -0.015812
# dtype: float64

# %% [markdown]
# as we can see now there is no skewness in our data

# %%
df_new
# Out:
#       W    R    AB             H   2B  3B   HR   BB    SO   SB   RA   ER  \
# 0    95  724  5575  7.216450e-16  300  42  139  383   973  104  641  601
# 1    83  696  5467 -4.163336e-16  277  44  156  439  1264   70  700  653
# 2    81  669  5439 -2.775558e-17  303  29  141  533  1157   86  640  584
# 3    76  622  5533 -1.387779e-16  260  27  136  404  1231   68  701  643
# 4    74  689  5605  8.465451e-16  289  49  151  455  1259   83  803  746
# 6    87  764  5567  0.000000e+00  272  19  212  554  1227   63  698  652
# 7    81  713  5485 -2.359224e-16  246  20  217  418  1331   44  693  646
# 8    80  644  5485 -1.249001e-16  278  32  167  436  1310   87  642  604
# 9    78  748  5640  7.077672e-16  294  33  161  478  1148   71  753  694
# 10   88  751  5511  1.665335e-16  279  32  172  503  1233  101  733  680
# 11   86  729  5459 -2.914335e-16  278  26  230  486  1392  121  618  572
# 12   85  661  5417 -5.828671e-16  243  21  176  435  1150   52  675  630
# ...

# %%
df_new=pd.DataFrame(df_new)

# %% [markdown]
# # Scaling the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
df2=pd.DataFrame(scaler.fit_transform(df_new),columns=df_new.columns)

# %%
df2
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.416025  0.959398  0.830084  1.685685  1.556538  1.010845 -0.765863
# 1   0.239947  0.331147 -0.702831 -0.970749  0.201171  1.208917 -0.181389
# 2   0.043934 -0.274666 -1.100253 -0.063674  1.733325 -0.276617 -0.697101
# 3  -0.446099 -1.329231  0.233951 -0.322838 -0.800621 -0.474688 -0.869006
# 4  -0.642112  0.174084  1.255894  1.977245  0.908319  1.704094 -0.353293
# 5   0.631973  1.856900  0.716535  0.001117 -0.093474 -1.266972  1.743939
# 6   0.043934  0.712585 -0.447345 -0.549607 -1.625627 -1.167936  1.915843
# 7  -0.054073 -0.835605 -0.447345 -0.290443  0.260100  0.020490  0.196801
# 8  -0.250086  1.497899  1.752672  1.653290  1.202964  0.119526 -0.009484
# 9   0.729980  1.565212 -0.078310  0.389864  0.319029  0.020490  0.368705
# 10  0.533967  1.071586 -0.816380 -0.679189  0.260100 -0.573723  2.362794
# 11  0.435960 -0.454167 -1.412514 -1.359496 -1.802414 -1.068901  0.506228
# ...

# %%
df2.mean()
# Out:
# W      1.990745e-16
# R     -1.232730e-15
# AB    -4.915608e-15
# H      1.531342e-17
# 2B    -1.150780e-15
# 3B     8.422382e-17
# HR    -2.143879e-16
# BB    -4.976862e-16
# SO     9.704881e-16
# SB     3.177535e-16
# RA     4.440892e-16
# ER     7.962979e-16
# ERA   -7.809845e-16
# CG     1.914178e-17
# SHO    0.000000e+00
# SV     3.828355e-18
# E     -2.488431e-17
# dtype: float64

# %%
df2.std()
# Out:
# W      1.0177
# R      1.0177
# AB     1.0177
# H      1.0177
# 2B     1.0177
# 3B     1.0177
# HR     1.0177
# BB     1.0177
# SO     1.0177
# SB     1.0177
# RA     1.0177
# ER     1.0177
# ERA    1.0177
# CG     1.0177
# SHO    1.0177
# SV     1.0177
# E      1.0177
# dtype: float64

# %% [markdown]
# now our data is perfectly balanced

# %%
import statsmodels.api
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(x):
    vif=pd.DataFrame()
    vif['features']= df2.columns
    vif['VIF']= [variance_inflation_factor(df2.values,i) for i in range(df2.shape[1])]
    
    return(vif)

# %%
calc_vif(df2)
# Out:
#    features          VIF
# 0         W    20.787830
# 1         R    13.261559
# 2        AB    21.779309
# 3         H    10.211644
# 4        2B     4.092971
# 5        3B     3.327588
# 6        HR     9.063666
# 7        BB     3.656249
# 8        SO     2.827281
# 9        SB     2.008949
# 10       RA   217.847704
# 11       ER  2117.604816
# 12      ERA  1783.388782
# 13       CG     3.572456
# 14      SHO     3.381020
# 15       SV     9.567094
# 16        E     2.261570

# %% [markdown]
# there is very high multicollinearity in ER, &ERA

# %%
df2=df2.drop(['ER'],axis=1)

# %%
def calc_vif(x):
    vif=pd.DataFrame()
    vif['features']= df2.columns
    vif['VIF']= [variance_inflation_factor(df2.values,i) for i in range(df2.shape[1])]
    
    return(vif)

# %%
calc_vif(df2)
# Out:
#    features         VIF
# 0         W   20.370869
# 1         R   11.256258
# 2        AB    8.512229
# 3         H    9.412441
# 4        2B    3.898504
# 5        3B    3.245255
# 6        HR    7.565285
# 7        BB    3.635023
# 8        SO    2.803961
# 9        SB    1.821727
# 10       RA  169.160097
# 11      ERA  198.785567
# 12       CG    3.343446
# 13      SHO    3.297109
# 14       SV    7.308172
# 15        E    2.206833

# %%
df2=df2.drop(['ERA'],axis=1)

# %%
def calc_vif(x):
    vif=pd.DataFrame()
    vif['features']= df2.columns
    vif['VIF']= [variance_inflation_factor(df2.values,i) for i in range(df2.shape[1])]
    
    return(vif)

# %%
calc_vif(df2)
# Out:
#    features        VIF
# 0         W  15.113133
# 1         R  10.316113
# 2        AB   5.289635
# 3         H   7.464759
# 4        2B   3.511025
# 5        3B   2.996345
# 6        HR   6.860749
# 7        BB   3.058263
# 8        SO   2.360043
# 9        SB   1.821727
# 10       RA   9.627646
# 11       CG   3.041528
# 12      SHO   3.188271
# 13       SV   5.766999
# 14        E   2.181526

# %% [markdown]
# As we can see now there is no multicollinearity in our data now

# %%
x=df2.drop('W',axis=1)
y=df2['W']

# %%
from sklearn.metrics import accuracy_score,mean_squared_error,mean_absolute_error

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)
    print(f'At random state{i}, The training accuracy is :-{r2_score(y_train,LR_predict_train)}')
    print(f'At random state{i}, The test accuracy is :-{r2_score(y_test,LR_predict_test)}')
    print('\n')
# Out:
# At random state0, The training accuracy is :-0.9712650794505755
# At random state0, The test accuracy is :-0.23537617274127176
#
#
# At random state1, The training accuracy is :-0.958571273110417
# At random state1, The test accuracy is :-0.5172695022586935
#
#
# At random state2, The training accuracy is :-0.9304979049443013
# At random state2, The test accuracy is :--0.22871264717179818
#
#
# At random state3, The training accuracy is :-0.9530462039223646
# At random state3, The test accuracy is :-0.5788411272074112
#
#
# At random state4, The training accuracy is :-0.949503586771044
# At random state4, The test accuracy is :-0.7967209905319892
#
#
# At random state5, The training accuracy is :-0.9510173128463817
# At random state5, The test accuracy is :-0.27260407064115766
#
#
# At random state6, The training accuracy is :-0.9506172788982984
# At random state6, The test accuracy is :-0.7174536741683675
#
#
# At random state7, The training accuracy is :-0.9351311364444398
# ...

# %% [markdown]
# the highest accuracy is at random state 47

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=47)

# %%
x_train.shape
# Out:
# (23, 14)

# %%
x_test.shape
# Out:
# (6, 14)

# %%
y_train.shape
# Out:
# (23,)

# %%
y_test.shape
# Out:
# (6,)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.score(x_train,y_train))
# Out:
# 0.9148759772991343

# %%
lr_predict=lr.predict(x_test)

# %%
lr_predict_train=lr.predict(x_train)

# %%
print("Mean_squared_error:",mean_squared_error(lr_predict,y_test))
print("Mean_absolute_error:",mean_absolute_error(lr_predict,y_test))
print("r2_score:",r2_score(lr_predict,y_test))
# Out:
# Mean_squared_error: 0.03718784789164357
# Mean_absolute_error: 0.15954341376225167
# r2_score: 0.9623883285444188

# %%
print("Mean_squared_error:",mean_squared_error(lr_predict_train,y_train))
print("Mean_absolute_error:",mean_absolute_error(lr_predict_train,y_train))
print("r2_score:",r2_score(lr_predict_train,y_train))
# Out:
# Mean_squared_error: 0.08000817764990505
# Mean_absolute_error: 0.23395612442442332
# r2_score: 0.9069556696065341

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor()

# %%
sgd.fit(x_train,y_train)
# Out:
# SGDRegressor()

# %%
predict=lr.predict(x_test)

# %%
predict_train=lr.predict(x_train)

# %%
print("Mean_squared_error:",mean_squared_error(predict,y_test))
print("Mean_absolute_error:",mean_absolute_error(predict,y_test))
print("r2_score:",r2_score(predict,y_test))
# Out:
# Mean_squared_error: 0.03718784789164357
# Mean_absolute_error: 0.15954341376225167
# r2_score: 0.9623883285444188

# %%
print("Mean_squared_error:",mean_squared_error(predict_train,y_train))
print("Mean_absolute_error:",mean_absolute_error(predict_train,y_train))
print("r2_score:",r2_score(predict_train,y_train))
# Out:
# Mean_squared_error: 0.08000817764990505
# Mean_absolute_error: 0.23395612442442332
# r2_score: 0.9069556696065341

# %%
from sklearn.neighbors import KNeighborsRegressor as KNN

# %%
model= KNN()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
pred=lr.predict(x_test)

# %%
pred_train=lr.predict(x_train)

# %%
print("Mean_squared_error:",mean_squared_error(pred_train,y_train))
print("Mean_absolute_error:",mean_absolute_error(pred_train,y_train))
print("r2_score:",r2_score(pred_train,y_train))
# Out:
# Mean_squared_error: 0.08000817764990505
# Mean_absolute_error: 0.23395612442442332
# r2_score: 0.9069556696065341

# %%
from sklearn.svm import SVR

# %%
model2=SVR()

# %%
model2.fit(x_train,y_train)
# Out:
# SVR()

# %%
pred=lr.predict(x_test)

# %%
pred_train=lr.predict(x_train)

# %%
print("Mean_squared_error:",mean_squared_error(y_test,pred))
print("Mean_absolute_error:",mean_absolute_error(y_test,pred))
print("r2_score:",r2_score(y_test,pred))
# Out:
# Mean_squared_error: 0.03718784789164357
# Mean_absolute_error: 0.15954341376225167
# r2_score: 0.9693270786684963

# %%
print("Mean_squared_error:",mean_squared_error(y_train,pred_train))
print("Mean_absolute_error:",mean_absolute_error(y_train,pred_train))
print("r2_score:",r2_score(y_train,pred_train))
# Out:
# Mean_squared_error: 0.08000817764990505
# Mean_absolute_error: 0.23395612442442332
# r2_score: 0.9148759772991343

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
predi=lr.predict(x_test)

# %%
predi_train=lr.predict(x_train)

# %%
print("Mean_squared_error:",mean_squared_error(y_test,predi))
print("Mean_absolute_error:",mean_absolute_error(y_test,predi))
print("r2_score:",r2_score(y_test,predi))
# Out:
# Mean_squared_error: 0.03718784789164357
# Mean_absolute_error: 0.15954341376225167
# r2_score: 0.9693270786684963

# %%
print("Mean_squared_error:",mean_squared_error(y_train,predi_train))
print("Mean_absolute_error:",mean_absolute_error(y_train,predi_train))
print("r2_score:",r2_score(y_train,predi_train))
# Out:
# Mean_squared_error: 0.08000817764990505
# Mean_absolute_error: 0.23395612442442332
# r2_score: 0.9148759772991343

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
Rfr=RandomForestRegressor()

# %%
Rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
predi=lr.predict(x_test)

# %%
predi_train=lr.predict(x_train)

# %%
print("Mean_squared_error:",mean_squared_error(y_test,predi))
print("Mean_absolute_error:",mean_absolute_error(y_test,predi))
print("r2_score:",r2_score(y_test,predi))
# Out:
# Mean_squared_error: 0.03718784789164357
# Mean_absolute_error: 0.15954341376225167
# r2_score: 0.9693270786684963

# %%
print("Mean_squared_error:",mean_squared_error(y_train,predi_train))
print("Mean_absolute_error:",mean_absolute_error(y_train,predi_train))
print("r2_score:",r2_score(y_train,predi_train))
# Out:
# Mean_squared_error: 0.08000817764990505
# Mean_absolute_error: 0.23395612442442332
# r2_score: 0.9148759772991343

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
ls=Lasso()
Z=GridSearchCV(ls,parameters)
Z.fit(x_train,y_train)
print(Z.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %%
ls=Lasso(alpha=0.1,random_state=0)
ls.fit(x_train,y_train)
pred=ls.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
# Out:
# R2_score: 0.916498155643276
# mean_squared_error: 0.1012376308421652
# mean_absolute_error: 0.2600726360917997

# %% [markdown]
# lasso is best suiting our model

# %%
pred=ls.predict(x_train)
print('R2_score:',r2_score(y_train,pred))
print('mean_squared_error:',mean_squared_error(y_train,pred))
print('mean_absolute_error:',mean_absolute_error(y_train,pred))
# Out:
# R2_score: 0.8666568593857061
# mean_squared_error: 0.12532938815820555
# mean_absolute_error: 0.2939155060196255

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
rg=Ridge()
Z=GridSearchCV(rg,parameters)
Z.fit(x_train,y_train)
print(Z.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
rg=Ridge(alpha=10,random_state=0)
rg.fit(x_train,y_train)
pred=rg.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
# Out:
# R2_score: 0.7991172928703901
# mean_squared_error: 0.24355018147960938
# mean_absolute_error: 0.4421447892212795

# %%
pred=rg.predict(x_train)
print('R2_score:',r2_score(y_train,pred))
print('mean_squared_error:',mean_squared_error(y_train,pred))
print('mean_absolute_error:',mean_absolute_error(y_train,pred))
# Out:
# R2_score: 0.8569043067127432
# mean_squared_error: 0.13449582487067707
# mean_absolute_error: 0.30091108074552897

# %% [markdown]
# # cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
def mse_cv(model,x,y):
    mse=cross_val_score(model,x,y,cv=10)
    return(mse)

# %%
models=[LinearRegression(),
        Ridge(),
        Lasso(),
        SVR(kernel='linear')
        ,SVR(kernel='poly'),
        SVR(kernel='rbf'),
        RandomForestRegressor(),
        DecisionTreeRegressor(),
        KNN()]

# %%
names = ['LR','R','L','svr','svr_p','svr_r','RF','DTR','KNN']

# %%
for model,name in zip(models,names):
    score = mse_cv(model,x,y)
    print("{}   : {:.6f}, {:4f}".format(name,score.mean(),score.std()))
# Out:
# LR   : -3.837829, 8.517194
# R   : -3.481848, 8.406540
# L   : -6.286729, 9.578407
# svr   : -3.010933, 7.669582
# svr_p   : -3.589400, 8.364811
# svr_r   : -6.401441, 10.303479
# RF   : -8.697892, 17.027662
# DTR   : -16.734565, 31.309768
# KNN   : -3.881542, 9.450506

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter={'alpha':[0.01,0.1,1.0,10.26],
          'selection':['cyclic','random'],
          "max_iter":[2,4,6,8,10],
          "fit_intercept":['bool']}

# %%
GVC=GridSearchCV(Lasso(),parameter,cv=5)

# %%
GVC.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random']})

# %%
GVC.best_params_
# Out:
# {'alpha': 0.1, 'fit_intercept': 'bool', 'max_iter': 4, 'selection': 'random'}

# %%
best_model=Lasso(alpha=0.1,fit_intercept='bool',max_iter=4,selection='random')
best_model.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1, fit_intercept='bool', max_iter=4, selection='random')

# %%
predict=best_model.predict(x_train)

# %%
predict_test=best_model.predict(x_test)

# %%
print('R2_score:',r2_score(y_train,predict))
print('mean_squared_error:',mean_squared_error(y_train,predict))
print('mean_absolute_error:',mean_absolute_error(y_train,predict))
# Out:
# R2_score: 0.8596826496715115
# mean_squared_error: 0.13188445677546082
# mean_absolute_error: 0.2871746979667331

# %%
print('R2_score:',r2_score(y_test,predict_test))
print('mean_squared_error:',mean_squared_error(y_test,predict_test))
print('mean_absolute_error:',mean_absolute_error(y_test,predict_test))
# Out:
# R2_score: 0.8614022480840176
# mean_squared_error: 0.16803590569906204
# mean_absolute_error: 0.38186375989025034

# %% [markdown]
# we are getting 86% accuracy

# %%
import pickle

# %%
saved_model=pickle.dumps(best_model)

# %%
model_from_pickle=pickle.loads(saved_model)

# %%
model_from_pickle.predict(x_test)
# Out:
# array([ 1.43913035, -1.03832008, -0.78518554,  0.29668166, -0.01721246,
#        -1.19938876])

# %%
model_from_pickle.predict(x_train)
# Out:
# array([ 0.9201707 ,  0.47723078,  1.0991739 , -0.36037499,  0.42633476,
#         0.95481449, -0.79800337, -1.09204082, -1.56752133,  0.24337886,
#         0.15518624, -0.78011186, -1.17439161,  0.30407799,  0.34072842,
#        -0.81633443,  1.13449157,  0.83021928,  0.42851071,  0.04089996,
#        -1.05912204,  0.12779071,  0.88135367])

# %%
pd.DataFrame([model_from_pickle.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                   0         1         2         3         4         5
# Predicted  1.439130 -1.038320 -0.785186  0.296682 -0.017212 -1.199389
# Original   1.906058 -0.446099 -0.642112  0.533967 -0.446099 -1.622177
